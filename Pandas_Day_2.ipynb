# %%
import pandas as pd
import numpy as np

# %%
arr = np.random.randint(40, 99, 24).reshape(6,4)
arr
# Out:
# array([[85, 56, 54, 76],
#        [49, 98, 70, 40],
#        [66, 73, 56, 79],
#        [75, 46, 47, 73],
#        [57, 41, 69, 87],
#        [67, 56, 45, 96]])

# %%
# Creating Dataframe
df = pd.DataFrame(arr, columns=["Math", "English", "Physics", "Sport"])

# Adding Column
df["Std_Name"] = ["Sachin", "Rohit", "Shubhaman", "Virat", "Ravindra","Rinku"] 

# Changing Column Position
cols = ["Std_Name", "Math", "English", "Physics", "Sport"]
df = df[cols]
df.head(3)
# Out:
#     Std_Name  Math  English  Physics  Sport
# 0     Sachin    85       56       54     76
# 1      Rohit    49       98       70     40
# 2  Shubhaman    66       73       56     79

# %%
df1 = df[["Std_Name", "Math", "English"]]
df2 = df[["Std_Name", "Physics", "Sport"]]

# %%
df1.head(2), df2.head(2)
# Out:
# (  Std_Name  Math  English
#  0   Sachin    85       56
#  1    Rohit    49       98,
#    Std_Name  Physics  Sport
#  0   Sachin       54     76
#  1    Rohit       70     40)

# %%
type((df1.head(2), df2.head(2)))
# Out:
# tuple

# %%
df1.join(df2, on="Std_Name", how="Inner")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df1.join(df2.reindex("Std_Name"), on="Std_Name", how="Inner")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5141, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5122 @doc(
#    5123     NDFrame.reindex,
#    5124     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5139     tolerance=None,
#    5140 ) -> DataFrame:
# -> 5141     return super().reindex(
#    5142         labels=labels,
#    5143         index=index,
#    5144         columns=columns,
#    5145         axis=axis,
#    5146         method=method,
#    5147         copy=copy,
#    5148         level=level,
#    5149         fill_value=fill_value,
#    5150         limit=limit,
#    5151         tolerance=tolerance,
#    5152     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:5521, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5518     return self._reindex_multi(axes, copy, fill_value)
#    5520 # perform the reindex on the axes
# -> 5521 return self._reindex_axes(
#    5522     axes, level, limit, tolerance, method, fill_value, copy
#    5523 ).__finalize__(self, method="reindex")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:5544, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5541     continue
#    5543 ax = self._get_axis(a)
# -> 5544 new_index, indexer = ax.reindex(
#    5545     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5546 )
#    5548 axis = self._get_axis_number(a)
#    5549 obj = obj._reindex_with_indexers(
#    5550     {axis: [new_index, indexer]},
#    5551     fill_value=fill_value,
#    5552     copy=copy,
#    5553     allow_dups=False,
#    5554 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:4407, in Index.reindex(self, target, method, level, limit, tolerance)
#    4405     target = idx[:0]
#    4406 else:
# -> 4407     target = ensure_index(target)
#    4409 if level is not None and (
#    4410     isinstance(self, ABCMultiIndex) or isinstance(target, ABCMultiIndex)
#    4411 ):
#    4412     if method is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7569, in ensure_index(index_like, copy)
#    7567         return Index(index_like, copy=copy, tupleize_cols=False)
#    7568 else:
# -> 7569     return Index(index_like, copy=copy)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:524, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     521         data = com.asarray_tuplesafe(data, dtype=_dtype_obj)
#     523 elif is_scalar(data):
# --> 524     raise cls._raise_scalar_data_error(data)
#     525 elif hasattr(data, "__array__"):
#     526     return Index(np.asarray(data), dtype=dtype, copy=copy, name=name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:5265, in Index._raise_scalar_data_error(cls, data)
#    5260 @final
#    5261 @classmethod
#    5262 def _raise_scalar_data_error(cls, data):
#    5263     # We return the TypeError so that we can raise it from the constructor
#    5264     #  in order to keep mypy happy
# -> 5265     raise TypeError(
#    5266         f"{cls.__name__}(...) must be called with a collection of some "
#    5267         f"kind, {repr(data) if not isinstance(data, np.generic) else str(data)} "
#    5268         "was passed"
#    5269     )
#
# TypeError: Index(...) must be called with a collection of some kind, 'Std_Name' was passed

# %%
df1.merge(df2, on="Std_Name", how="outer")
# Out:
#     Std_Name  Math  English  Physics  Sport
# 0     Sachin    85       56       54     76
# 1      Rohit    49       98       70     40
# 2  Shubhaman    66       73       56     79
# 3      Virat    75       46       47     73
# 4   Ravindra    57       41       69     87
# 5      Rinku    67       56       45     96

# %%
df1 = df1[df1["Std_Name"]!="Sachin"]

# %%
df1
# Out:
#     Std_Name  Math  English
# 1      Rohit    49       98
# 2  Shubhaman    66       73
# 3      Virat    75       46
# 4   Ravindra    57       41
# 5      Rinku    67       56

# %%
df2 = df2[df2["Std_Name"]!="Rinku"]
df2
# Out:
#     Std_Name  Physics  Sport
# 0     Sachin       54     76
# 1      Rohit       70     40
# 2  Shubhaman       56     79
# 3      Virat       47     73
# 4   Ravindra       69     87

# %%
df1.merge(df2, on="Std_Name", how="left")
# Out:
#     Std_Name  Math  English  Physics  Sport
# 0      Rohit    49       98     70.0   40.0
# 1  Shubhaman    66       73     56.0   79.0
# 2      Virat    75       46     47.0   73.0
# 3   Ravindra    57       41     69.0   87.0
# 4      Rinku    67       56      NaN    NaN

# %%
df1
# Out:
#     Std_Name  Math  English
# 1      Rohit    49       98
# 2  Shubhaman    66       73
# 3      Virat    75       46
# 4   Ravindra    57       41
# 5      Rinku    67       56

# %%
df2
# Out:
#     Std_Name  Physics  Sport
# 0     Sachin       54     76
# 1      Rohit       70     40
# 2  Shubhaman       56     79
# 3      Virat       47     73
# 4   Ravindra       69     87

# %%
df1.merge(df2, on="Std_Name", how="right")
# Out:
#     Std_Name  Math  English  Physics  Sport
# 0     Sachin   NaN      NaN       54     76
# 1      Rohit  49.0     98.0       70     40
# 2  Shubhaman  66.0     73.0       56     79
# 3      Virat  75.0     46.0       47     73
# 4   Ravindra  57.0     41.0       69     87

# %%
df1.merge(df2, how="cross", right_index=False)

# need to review
# Out:
#    Std_Name_x  Math  English Std_Name_y  Physics  Sport
# 0       Rohit    49       98     Sachin       54     76
# 1       Rohit    49       98      Rohit       70     40
# 2       Rohit    49       98  Shubhaman       56     79
# 3       Rohit    49       98      Virat       47     73
# 4       Rohit    49       98   Ravindra       69     87
# 5   Shubhaman    66       73     Sachin       54     76
# 6   Shubhaman    66       73      Rohit       70     40
# 7   Shubhaman    66       73  Shubhaman       56     79
# 8   Shubhaman    66       73      Virat       47     73
# 9   Shubhaman    66       73   Ravindra       69     87
# 10      Virat    75       46     Sachin       54     76
# 11      Virat    75       46      Rohit       70     40
# 12      Virat    75       46  Shubhaman       56     79
# 13      Virat    75       46      Virat       47     73
# 14      Virat    75       46   Ravindra       69     87
# 15   Ravindra    57       41     Sachin       54     76
# 16   Ravindra    57       41      Rohit       70     40
# 17   Ravindra    57       41  Shubhaman       56     79
# 18   Ravindra    57       41      Virat       47     73
# 19   Ravindra    57       41   Ravindra       69     87
# 20      Rinku    67       56     Sachin       54     76
# 21      Rinku    67       56      Rohit       70     40
# 22      Rinku    67       56  Shubhaman       56     79
# 23      Rinku    67       56      Virat       47     73
# 24      Rinku    67       56   Ravindra       69     87

# %%
dict = {
    "Name":["Raju", "Shyam", "Babu", "Raju", "Shyam", "Babu", "Raju", "Babu"],
    "Month":["Jan", "Jan", "Jan", "Feb", "Feb", "Feb", "Mar", "Mar"],
    "Sales": [2300, 2100, 3100, 2400, 3200, 2000, 2400, 2500]
}

# %%
sales = pd.DataFrame(dict)
sales
# Out:
#     Name Month  Sales
# 0   Raju   Jan   2300
# 1  Shyam   Jan   2100
# 2   Babu   Jan   3100
# 3   Raju   Feb   2400
# 4  Shyam   Feb   3200
# 5   Babu   Feb   2000
# 6   Raju   Mar   2400
# 7   Babu   Mar   2500

# %%
pd.pivot(sales, columns="Month", index="Name", values="Sales")
# Out:
# Month     Feb     Jan     Mar
# Name
# Babu   2000.0  3100.0  2500.0
# Raju   2400.0  2300.0  2400.0
# Shyam  3200.0  2100.0     NaN

# %%
dict = {
    "Name":["Raju", "Shyam", "Babu", "Raju", "Shyam", "Babu", "Raju", "Babu", "Raju", "Shyam", "Babu", "Raju"],
    "Month":["Jan", "Jan", "Jan", "Feb", "Feb", "Feb", "Mar", "Mar", "Jan", "Jan", "Jan", "Feb"],
    "Sales": [2300, 2100, 3100, 2400, 3200, 2000, 2400, 2500, 3100, 2400, 3200, 2000]
}

# %%
new_sales = pd.DataFrame(dict)

# %%
new_sales
# Out:
#      Name Month  Sales
# 0    Raju   Jan   2300
# 1   Shyam   Jan   2100
# 2    Babu   Jan   3100
# 3    Raju   Feb   2400
# 4   Shyam   Feb   3200
# 5    Babu   Feb   2000
# 6    Raju   Mar   2400
# 7    Babu   Mar   2500
# 8    Raju   Jan   3100
# 9   Shyam   Jan   2400
# 10   Babu   Jan   3200
# 11   Raju   Feb   2000

# %%
pd.pivot_table(new_sales, columns="Month", index="Name", values="Sales", aggfunc="sum")
# Out:
# Month     Feb     Jan     Mar
# Name
# Babu   2000.0  6300.0  2500.0
# Raju   4400.0  5400.0  2400.0
# Shyam  3200.0  4500.0     NaN
